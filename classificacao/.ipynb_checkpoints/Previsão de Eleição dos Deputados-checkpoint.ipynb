# %% [markdown]
# # Previsão de Eleição dos Deputados
# Este documento tem objetivo de prever se determinado candidato será eleito ou não baseado em eleições passadas, utilizando aprendizagem de máquina para isto.

# %%
import pandas as pd
import numpy as np
import matplotlib
from sklearn import preprocessing

# %% [markdown]
# Para realizar a modelagem dos algortmos preditivos, vamos utilizar no treino dados referentes às eleições de 2006 e 2010 e para o teste dados das eleições de 2014.

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
pd.set_option('display.max_columns', 500)
train.head()
# Out:
#     ano  sequencial_candidato                             nome  uf partido  \
# 0  2006                 10001      JOSÉ LUIZ NOGUEIRA DE SOUSA  AP      PT
# 1  2006                 10002                LOIVA DE OLIVEIRA  RO      PT
# 2  2006                 10002  MARIA DALVA DE SOUZA FIGUEIREDO  AP      PT
# 3  2006                 10002                   ROMALDO MILANI  MS   PRONA
# 4  2006                 10003           ANSELMO DE JESUS ABREU  RO      PT
#
#    quantidade_doacoes  quantidade_doadores  total_receita  media_receita  \
# 0                   6                    6       16600.00        2766.67
# 1                  13                   13       22826.00        1755.85
# 2                  17                   16      158120.80        9301.22
# 3                   6                    6        3001.12         500.19
# 4                  48                   48      119820.00        2496.25
#
#    recursos_de_outros_candidatos.comites  recursos_de_pessoas_fisicas  \
# 0                                    0.0                       9000.0
# 1                                 6625.0                      15000.0
# 2                                 2250.0                      34150.0
# 3                                    0.0                       1150.0
# 4                                    0.0                      50878.0
#
#    recursos_de_pessoas_juridicas  recursos_proprios  \
# 0                        6300.00             1300.0
# 1                        1000.00              201.0
# 2                       62220.80            59500.0
# 3                        1101.12              750.0
# 4                           0.00            68942.0
#
#    recursos_de_partido_politico  quantidade_despesas  quantidade_fornecedores  \
# 0                           0.0                   14                       14
# 1                           0.0                   24                       23
# 2                           0.0                  123                      108
# 3                           0.0                    8                        8
# 4                           0.0                  133                      120
#
#    total_despesa  media_despesa             cargo       sexo  \
# 0       16583.60        1184.54  DEPUTADO FEDERAL  MASCULINO
# 1       20325.99         846.92  DEPUTADO FEDERAL   FEMININO
# 2      146011.70        1187.09  DEPUTADO FEDERAL   FEMININO
# 3        3001.12         375.14  DEPUTADO FEDERAL  MASCULINO
# 4      116416.64         875.31  DEPUTADO FEDERAL  MASCULINO
#
#                           grau estado_civil                   ocupacao  \
# 0        ENSINO MÉDIO COMPLETO    CASADO(A)                   VEREADOR
# 1            SUPERIOR COMPLETO  SOLTEIRO(A)  SERVIDOR PÚBLICO ESTADUAL
# 2            SUPERIOR COMPLETO     VIÚVO(A)                   PEDAGOGO
# 3      ENSINO MÉDIO INCOMPLETO    CASADO(A)          MILITAR REFORMADO
# 4  ENSINO FUNDAMENTAL COMPLETO    CASADO(A)                   DEPUTADO
#
#      situacao
# 0  nao_eleito
# 1  nao_eleito
# 2      eleito
# 3  nao_eleito
# 4      eleito

# %%
test.head()
# Out:
#     ano  sequencial_candidato                             nome  uf partido  \
# 0  2014           10000000135          EMERSON DA SILVA SANTOS  AC    PSOL
# 1  2014           10000000142         GERALDO SILVA DOS SANTOS  AC    PSOL
# 2  2014           10000000158  CARLOS CESAR CORREIA DE MESSIAS  AC     PSB
# 3  2014           10000000161               IDESIO LUIS FRANKE  AC      PT
# 4  2014           10000000163          LEONARDO CUNHA DE BRITO  AC      PT
#
#    quantidade_doacoes  quantidade_doadores  total_receita  media_receita  \
# 0                   3                    3        1580.00         526.67
# 1                   5                    5        3180.00         636.00
# 2                  40                   38      336793.13        8419.83
# 3                  29                   29      156719.32        5404.11
# 4                 160                  146      737073.00        4606.71
#
#    recursos_de_outros_candidatos.comites  recursos_de_pessoas_fisicas  \
# 0                                   0.00                      1500.00
# 1                                   0.00                      3100.00
# 2                                1923.07                     65700.00
# 3                               39122.32                     68783.84
# 4                               10000.00                    347073.00
#
#    recursos_de_pessoas_juridicas  recursos_proprios  \
# 0                           0.00               0.00
# 1                           0.00               0.00
# 2                      154170.06          115000.00
# 3                       17000.00            6813.16
# 4                      277000.00           78000.00
#
#    recursos_de_partido_politico  quantidade_despesas  quantidade_fornecedores  \
# 0                          80.0                    3                        3
# 1                          80.0                    6                        5
# 2                           0.0                  145                      139
# 3                       25000.0                  136                      121
# 4                       25000.0                  518                      354
#
#    total_despesa  media_despesa             cargo       sexo  \
# 0        1580.00         526.67  DEPUTADO FEDERAL  MASCULINO
# 1        3130.02         521.67  DEPUTADO FEDERAL  MASCULINO
# 2      326869.78        2254.27  DEPUTADO FEDERAL  MASCULINO
# 3      241016.07        1772.18  DEPUTADO FEDERAL  MASCULINO
# 4      567401.15        1095.37  DEPUTADO FEDERAL  MASCULINO
#
#                             grau estado_civil  \
# 0          ENSINO MÉDIO COMPLETO  SOLTEIRO(A)
# 1              SUPERIOR COMPLETO  SOLTEIRO(A)
# 2  ENSINO FUNDAMENTAL INCOMPLETO    CASADO(A)
# 3              SUPERIOR COMPLETO    CASADO(A)
# 4              SUPERIOR COMPLETO    CASADO(A)
#
#                                           ocupacao
# 0  CORRETOR DE IMÓVEIS, SEGUROS, TÍTULOS E VALORES
# 1                                        VIGILANTE
# 2                                           OUTROS
# 3                                         AGRÔNOMO
# 4                                         ADVOGADO

# %% [markdown]
# Como uma análise prévia para estes dados já tinham sido feitas, que podem ser vista neste [notebook](https://github.com/orionwinter/machine-learning/blob/master/regressao-varios-modelos/Previs%C3%A3o%20de%20Vota%C3%A7%C3%A3o%20de%20Deputados.ipynb), os dados numéricos são bastante desbalanceados, além de existirem valores faltantes. Vamos novamente contornar esses detalhes aplicando a função de log nos dados numéricos e substituindo os valores faltantes pela média da coluna. Além disso, os valores numéricos foram normalizados entre 0 e 1, para melhorar o desempenho dos modelos.

# %%
numeric_feats = train.dtypes[train.dtypes != "object"].index
train[numeric_feats] = np.log1p(train[numeric_feats])
test[numeric_feats] = np.log1p(test[numeric_feats])

train = train.fillna(train.mean())
test = test.fillna(test.mean())

numeric_feats = train.dtypes[train.dtypes != "object"].index
non_numeric_feats = train.dtypes[train.dtypes == "object"].index

min_max_scaler = preprocessing.MinMaxScaler()
train_normalized = min_max_scaler.fit_transform(train[numeric_feats])
test_normalized = min_max_scaler.fit_transform(test[numeric_feats])

train_normalized = pd.DataFrame(train_normalized, columns=train[numeric_feats].columns)
test_normalized = pd.DataFrame(test_normalized, columns=test[numeric_feats].columns)

train_normalized = pd.concat([train_normalized, train[non_numeric_feats].reset_index()], axis = 1, sort = False)
test_normalized = pd.concat([test_normalized, test[non_numeric_feats].reset_index()], axis = 1, sort = False)

train = train_normalized
test = test_normalized
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-82014d0e2851> in <module>()
#       9 non_numeric_feats = train.dtypes[train.dtypes == "object"].index
#      10
# ---> 11 min_max_scaler = preprocessing.MinMaxScaler()
#      12 train_normalized = min_max_scaler.fit_transform(train[numeric_feats])
#      13 test_normalized = min_max_scaler.fit_transform(test[numeric_feats])
#
# NameError: name 'preprocessing' is not defined

# %% [markdown]
# Primeiramente vamos verificar se existe desbalanceamento na variável alvo:

# %%
sit = train[["situacao"]].groupby(["situacao"]).size()
sit.plot(kind = "bar")

# %%
float(sit[0]) / float(sit[1])
# Out:
# 0.15554881746513038

# %% [markdown]
# Podemos ver que existem muito mais candidatos não eleitos do que eleitos, em uma proporção de 0.156, que é cerca de 1 eleito para cada 6 não eleitos.
#
# Como alguns algoritmos de classificação são bastante sensíveis ao desbalanceamento, isso poderia tendenciá-los a predizer pela classe majoritária, ou seja, ter uma tendência muito maior a prever que um deputado não foi eleito, visto este desbalanceamento.
#
# Para tratar este caso, vamos utilizar uma técnica de reamostragem chamada SMOTE(Synthetic Minority Over-sampling Technique) que é um algoritmo um pouco mais rebuscado que uma simples reamostragem da classe minoritária, visto que além de reamostrar modifica sinteticamente os dados reamostrados baseado nos demais da mesma classe.

# %%
from imblearn.over_sampling import SMOTE

def balanceia_dados(dados):
    sm = SMOTE(random_state=42)
    X = dados.loc[:, dados.columns != "situacao"]
    y = dados.situacao
    X_res, y_res = sm.fit_resample(X, y)
    dados_balanceados = pd.concat([X_res.reset_index(drop=True), y_res], axis=1)
    return dados_balanceados

train_bal = balanceia_dados(train)
